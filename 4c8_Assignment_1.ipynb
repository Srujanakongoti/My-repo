# %% [markdown]
# <a href="https://colab.research.google.com/github/Srujanakongoti/My-repo/blob/master/4c8_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

from zipfile import ZipFile
from urllib.request import urlretrieve

from IPython.display import Image
from google.colab.patches import cv2_imshow

# %matplotlib inline

# %%
def download_and_unzip(url, save_path):
    print(f"Downloading and extracting assests....", end="")

    # Downloading zip file using urllib package.
    urlretrieve(url, save_path)

    try:
        # Extracting zip file using the zipfile package.
        with ZipFile(save_path) as z:
            # Extract ZIP file contents in the same directory.
            z.extractall(os.path.split(save_path)[0])

        print("Done")

    except Exception as e:
        print("\nInvalid file.", e)

# %%
URL = r"https://www.dropbox.com/s/qhhlqcica1nvtaw/opencv_bootcamp_assets_NB1.zip?dl=1"

asset_zip_path = os.path.join(os.getcwd(), "opencv_bootcamp_assets_NB1.zip")

# Download if assest ZIP does not exists.
if not os.path.exists(asset_zip_path):
    download_and_unzip(URL, asset_zip_path)

# %% [markdown]
# ## **Question No 1:  Display First images from the dataset(1-10 images)**

# %%
img1=cv2.imread("checkerboard_18x18.png")
cv2_imshow(img1)
img2=cv2.imread("checkerboard_fuzzy_18x18.jpg")
cv2_imshow(img2)
img3=cv2.imread("coca-cola-logo.png")
cv2_imshow(img3)
img4=cv2.imread("checkerboard_84x84.jpg")
cv2_imshow(img4)
img5=cv2.imread("checkerboard_color.png")
cv2_imshow(img5)
img6=cv2.imread("New_Zealand_Lake.jpg")
cv2_imshow(img6)
# Out:
# <PIL.Image.Image image mode=RGB size=18x18>
# <PIL.Image.Image image mode=RGB size=18x18>
# <PIL.Image.Image image mode=RGB size=700x700>
# <PIL.Image.Image image mode=RGB size=84x84>
# <PIL.Image.Image image mode=RGB size=1800x1800>
# <PIL.Image.Image image mode=RGB size=840x600>

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

dataset_path = "/content/temp_extracted_images/Coffee_Tea"

# Get a list of image files in the folder
image_files = [f for f in os.listdir(dataset_path) if f.endswith(('.png', '.jpg', '.jpeg', '.gif'))]

# Take the first 10 images (or less if there are fewer than 10 images)
images_to_display = image_files[:10]

# Display the images
for img_file in images_to_display:
    img_path = os.path.join(dataset_path, img_file)
    img = Image.open(img_path)
    figsize=(2,2)
    plt.figure(figsize=figsize)
    plt.imshow(img)
    plt.axis('off')  # Hide axes for images
    plt.show()

# %% [markdown]
# ## **Question No 2: To Display the image by using cv2 imshow**

# %%
image=cv2.imread("coca-cola-logo.png",1)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=700x700>

# %% [markdown]
# ## **Question No 3: Crop the name Coca-cola and below lines from the Coca-cola logo image**

# %%
coke_img = cv2.imread("coca-cola-logo.png")
x, y, w, h = 0, 200, 700, 300
region_of_interest = coke_img[y:y+h, x:x+w]
cropped_image=region_of_interest[:,:, ::-1]
# cropped  the Coca-cola and below lines and displayed image in RGB
plt.imshow(cropped_image)

# %% [markdown]
# ## **Question No 4: Plot the red, Green, blue, BGR and RGB images**

# %%
# Split the image into the B,G,R components
coca_image = cv2.imread("coca-cola-logo.png", cv2.IMREAD_COLOR)
b, g, r = cv2.split(coca_image)

# Show the channels
plt.figure(figsize=[20, 10])
plt.subplot(151);plt.imshow(r, cmap="gray");plt.title("Red Channel")
plt.subplot(152);plt.imshow(g, cmap="gray");plt.title("Green Channel")
plt.subplot(153);plt.imshow(b, cmap="gray");plt.title("Blue Channel")

# converting b,g,r into BGR
imgBGR=cv2.merge((b ,g , r))
#show BGR image
plt.subplot(154);plt.imshow(imgBGR);plt.title("BGR")
# converting b,g,r into RGB
imgRGB=cv2.merge((r ,g ,b))
#show RGB image
plt.subplot(155);plt.imshow(imgRGB);plt.title("RGB")
# Out:
# Text(0.5, 1.0, 'RGB')

# %% [markdown]
# ## **Question No 5: Plot the both RGB and BGR images of Coco-cola logo**

# %%
image_coca=cv2.imread("coca-cola-logo.png",1)
plt.subplot(121);plt.imshow(image_coca[:,:,::-1]);plt.title("RGB")
plt.subplot(122);plt.imshow(image_coca);plt.title("BGR")
# Out:
# Text(0.5, 1.0, 'BGR')

# %% [markdown]
# ## **Question No 6: Plot the BGR2RGB and RGB2BGR images**

# %%
coca_image_RGB=cv2.cvtColor(coca_image , cv2.COLOR_BGR2RGB)
plt.subplot(121);plt.imshow(coca_image_RGB);plt.title("BGR2RGB")
coca_image_BGR=cv2.cvtColor(coca_image_RGB,cv2.COLOR_RGB2BGR)
plt.subplot(122);plt.imshow(coca_image_BGR);plt.title("RGB2BGR")
# Out:
# Text(0.5, 1.0, 'RGB2BGR')

# %% [markdown]
# ## **Question No 7: Save the images in the file name bvrit_cv_ex1.png**

# %%
img_NZ_rgb = cv2.imread("coca-cola-logo.png")

# %%
from IPython.display import Image, display
import cv2
cv2.imwrite("bvrit_cv_ex1.png", img_NZ_rgb)
display(Image(filename='bvrit_cv_ex1.png'))

# %%
# read the image as Color

img_NZ_rgb = cv2.imread("bvrit_cv_ex1.png", cv2.IMREAD_COLOR)
print("img_NZ_rgb shape (H, W, C) is:", img_NZ_rgb.shape)

img_NZ_bgr=cv2.cvtColor(img_NZ_rgb,cv2.COLOR_RGB2BGR)
img_NZ_bgr = cv2.imread("bvrit_cv_ex1.png", cv2.IMREAD_COLOR)
print("img_NZ_bgr shape (H, W, C) is:", img_NZ_bgr.shape)

# read the image as Grayscaled
img_NZ_gry = cv2.imread("bvrit_cv_ex1.png", cv2.IMREAD_GRAYSCALE)
print("img_NZ_gry shape (H, W) is:", img_NZ_gry.shape)
# Out:
# img_NZ_rgb shape (H, W, C) is: (700, 700, 3)
# img_NZ_bgr shape (H, W, C) is: (700, 700, 3)
# img_NZ_gry shape (H, W) is: (700, 700)

# %% [markdown]
# ## **Question No 8: Plot the Gray scale image and color image**

# %%
plt.figure(figsize=[20,5])
# plotting gray scale image
plt.subplot(131);plt.imshow(img_NZ_gry,cmap='gray');plt.title("gray scale image");
# plotting color images
#BGR
plt.subplot(132);plt.imshow(img_NZ_rgb);plt.title("color image");
#RGB
img_NZ_bgr=img_NZ_rgb[:,:,::-1]
plt.subplot(133);plt.imshow(img_NZ_bgr);plt.title("color image");
